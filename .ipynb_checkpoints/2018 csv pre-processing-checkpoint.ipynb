# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Hospital_Inpatient_Discharges_2017.csv')

# %%
df.head()
# Out:
#   Hospital Service Area Hospital County  Operating Certificate Number  \
# 0         Hudson Valley     Westchester                     5903001.0
# 1         Hudson Valley     Westchester                     5903001.0
# 2         Hudson Valley     Westchester                     5903001.0
# 3         Hudson Valley     Westchester                     5903001.0
# 4         Hudson Valley     Westchester                     5903001.0
#
#    Permanent Facility Id                     Facility Name Age Group  \
# 0                 1061.0  Montefiore Mount Vernon Hospital  30 to 49
# 1                 1061.0  Montefiore Mount Vernon Hospital  50 to 69
# 2                 1061.0  Montefiore Mount Vernon Hospital  30 to 49
# 3                 1061.0  Montefiore Mount Vernon Hospital  50 to 69
# 4                 1061.0  Montefiore Mount Vernon Hospital  18 to 29
#
#   Zip Code - 3 digits Gender   Race          Ethnicity  ...  \
# 0                 NaN      M  White  Not Span/Hispanic  ...
# 1                 105      M  White   Spanish/Hispanic  ...
# 2                 105      F  White            Unknown  ...
# 3                 105      F  White  Not Span/Hispanic  ...
# 4                 105      F  White   Spanish/Hispanic  ...
#
#   APR Risk of Mortality APR Medical Surgical Description  \
# 0                 Minor                          Medical
# 1              Moderate                          Medical
# 2              Moderate                          Medical
# 3              Moderate                          Medical
# 4                 Minor                          Medical
#
#           Payment Typology 1  Payment Typology 2  Payment Typology 3  \
# 0                   Medicare            Medicare            Self-Pay
# 1                   Medicaid            Medicaid            Self-Pay
# 2  Department of Corrections            Self-Pay                 NaN
# 3                   Medicaid            Medicaid            Self-Pay
# 4  Department of Corrections            Self-Pay                 NaN
#
#   Birth Weight  Abortion Edit Indicator Emergency Department Indicator  \
# 0          NaN                        N                              N
# 1          NaN                        N                              N
# 2          NaN                        N                              N
# 3          NaN                        N                              N
# 4          NaN                        N                              N
#
#    Total Charges Total Costs
# 0      114168.00    40464.04
# 1       58517.00    26046.50
# 2       39647.04    17397.59
# 3       36031.09    16118.84
# 4       30534.00    11921.05
#
# [5 rows x 34 columns]

# %%
df.columns
# Out:
# Index(['Hospital Service Area', 'Hospital County',
#        'Operating Certificate Number', 'Permanent Facility Id',
#        'Facility Name', 'Age Group', 'Zip Code - 3 digits', 'Gender', 'Race',
#        'Ethnicity', 'Length of Stay', 'Type of Admission',
#        'Patient Disposition', 'Discharge Year', 'CCS Diagnosis Code',
#        'CCS Diagnosis Description', 'CCS Procedure Code',
#        'CCS Procedure Description', 'APR DRG Code', 'APR DRG Description',
#        'APR MDC Code', 'APR MDC Description', 'APR Severity of Illness Code',
#        'APR Severity of Illness Description', 'APR Risk of Mortality',
#        'APR Medical Surgical Description', 'Payment Typology 1',
#        'Payment Typology 2', 'Payment Typology 3', 'Birth Weight',
#        'Abortion Edit Indicator', 'Emergency Department Indicator',
#        'Total Charges', 'Total Costs'],
#       dtype='object')

# %%
condition = df['APR Risk of Mortality'] == 'Minor'
df1 = df[condition]

# %%
df1.shape
# Out:
# (1338452, 34)

# %%
df1.head()
# Out:
#   Hospital Service Area Hospital County  Operating Certificate Number  \
# 0         Hudson Valley     Westchester                     5903001.0
# 4         Hudson Valley     Westchester                     5903001.0
# 6         Hudson Valley     Westchester                     5903001.0
# 8         Hudson Valley     Westchester                     5903001.0
# 9         Hudson Valley     Westchester                     5903001.0
#
#    Permanent Facility Id                     Facility Name Age Group  \
# 0                 1061.0  Montefiore Mount Vernon Hospital  30 to 49
# 4                 1061.0  Montefiore Mount Vernon Hospital  18 to 29
# 6                 1061.0  Montefiore Mount Vernon Hospital  30 to 49
# 8                 1061.0  Montefiore Mount Vernon Hospital  50 to 69
# 9                 1061.0  Montefiore Mount Vernon Hospital  50 to 69
#
#   Zip Code - 3 digits Gender                    Race          Ethnicity  ...  \
# 0                 NaN      M                   White  Not Span/Hispanic  ...
# 4                 105      F                   White   Spanish/Hispanic  ...
# 6                 105      F  Black/African American  Not Span/Hispanic  ...
# 8                 105      M  Black/African American  Not Span/Hispanic  ...
# 9                 107      F  Black/African American  Not Span/Hispanic  ...
#
#   APR Risk of Mortality APR Medical Surgical Description  \
# 0                 Minor                          Medical
# 4                 Minor                          Medical
# 6                 Minor                          Medical
# 8                 Minor                          Medical
# 9                 Minor                          Medical
#
#           Payment Typology 1        Payment Typology 2  Payment Typology 3  \
# 0                   Medicare                  Medicare            Self-Pay
# 4  Department of Corrections                  Self-Pay                 NaN
# 6                   Medicaid                  Self-Pay                 NaN
# 8                   Medicaid                  Medicaid            Self-Pay
# 9   Private Health Insurance  Private Health Insurance            Self-Pay
#
#   Birth Weight  Abortion Edit Indicator Emergency Department Indicator  \
# 0          NaN                        N                              N
# 4          NaN                        N                              N
# 6          NaN                        N                              N
# 8          NaN                        N                              N
# 9          NaN                        N                              N
#
#    Total Charges Total Costs
# 0       114168.0    40464.04
# 4        30534.0    11921.05
# 6        20511.0     9103.80
# 8        31034.0    12649.61
# 9        25027.0     9751.06
#
# [5 rows x 34 columns]

# %%
#listing the categories in the MDC description

df1['APR MDC Description'].unique()
# Out:
# array(['Mental Diseases and Disorders',
#        'Infectious and Parasitic Diseases, Systemic or Unspecified Sites',
#        'Diseases and Disorders of the Circulatory System',
#        'Ear, Nose, Mouth, Throat and Craniofacial Diseases and Disorders',
#        'Diseases and Disorders of the Respiratory System',
#        'Pregnancy, Childbirth and the Puerperium',
#        'Diseases and Disorders of the Musculoskeletal System and Conn Tissue',
#        'Newborns and Other Neonates with Conditions Originating in the Perinatal Period',
#        'Endocrine, Nutritional and Metabolic Diseases and Disorders',
#        'Diseases and Disorders of the Digestive System',
#        'Diseases and Disorders of the Hepatobiliary System and Pancreas',
#        'Poisonings, Toxic Effects, Other Injuries and Other Complications of Treatment',
#        'Alcohol/Drug Use and Alcohol/Drug Induced Organic Mental Disorders',
#        'Diseases and Disorders of the Kidney and Urinary Tract', 'Burns',
#        'Diseases and Disorders of the Nervous System',
#        'Diseases and Disorders of the Skin, Subcutaneous Tissue and Breast',
#        'Rehabilitation, Aftercare, Other Factors Influencing Health Status and Other Health Service Contacts',
#        'Diseases and Disorders of Blood, Blood Forming Organs and Immunological Disorders',
#        'Diseases and Disorders of the Male Reproductive System',
#        'Diseases and Disorders of the Eye',
#        'Diseases and Disorders of the Female Reproductive System',
#        'Lymphatic, Hematopoietic, Other Malignancies, Chemotherapy and Radiotherapy',
#        'Human Immunodeficiency Virus Infections',
#        'Multiple Significant Trauma'], dtype=object)

# %%
#filtering by potential respiratory conditions relating to pollution in the 'APR MDC Description' column, 
#resetting index

filtered = ['Diseases and Disorders of the Respiratory System']

condition = df1['APR MDC Description'].isin(filtered)
df2 = df1[condition]
df2 = df2.reset_index(drop = True)

# %%
df2.shape
# Out:
# (64116, 34)

# %%
df2.head()
# Out:
#   Hospital Service Area Hospital County  Operating Certificate Number  \
# 0         Hudson Valley     Westchester                     5904001.0
# 1         Hudson Valley        Sullivan                     5263000.0
# 2         Hudson Valley        Sullivan                     5263000.0
# 3         Hudson Valley        Sullivan                     5263000.0
# 4         New York City       Manhattan                     7002024.0
#
#    Permanent Facility Id                     Facility Name    Age Group  \
# 0                 1072.0  Montefiore New Rochelle Hospital     18 to 29
# 1                  971.0  Catskill Regional Medical Center  70 or Older
# 2                  971.0  Catskill Regional Medical Center      0 to 17
# 3                  971.0  Catskill Regional Medical Center     18 to 29
# 4                 1456.0              Mount Sinai Hospital      0 to 17
#
#   Zip Code - 3 digits Gender        Race          Ethnicity  ...  \
# 0                 108      M  Other Race   Spanish/Hispanic  ...
# 1                 127      F       White   Spanish/Hispanic  ...
# 2                 127      F       White  Not Span/Hispanic  ...
# 3                 OOS      M       White  Not Span/Hispanic  ...
# 4                 100      F  Other Race  Not Span/Hispanic  ...
#
#   APR Risk of Mortality APR Medical Surgical Description  \
# 0                 Minor                          Medical
# 1                 Minor                          Medical
# 2                 Minor                          Medical
# 3                 Minor                          Medical
# 4                 Minor                          Medical
#
#        Payment Typology 1        Payment Typology 2  Payment Typology 3  \
# 0                Medicaid                  Self-Pay                 NaN
# 1                Medicare  Private Health Insurance                 NaN
# 2  Blue Cross/Blue Shield                       NaN                 NaN
# 3                Medicaid                       NaN                 NaN
# 4                Medicaid                  Medicaid            Self-Pay
#
#   Birth Weight  Abortion Edit Indicator Emergency Department Indicator  \
# 0          NaN                        N                              N
# 1          NaN                        N                              Y
# 2          NaN                        N                              Y
# 3          NaN                        N                              Y
# 4          NaN                        N                              N
#
#    Total Charges Total Costs
# 0      250097.00   104394.14
# 1       11849.56     3360.90
# 2       11148.97     3240.32
# 3       11208.22     3144.27
# 4       15584.75    11895.63
#
# [5 rows x 34 columns]

# %%
#dropping irrelevant columns
dropping_columns = [ 'Operating Certificate Number', 'Permanent Facility Id', 'Race', 'Ethnicity', 'Patient Disposition','CCS Procedure Code',
      'CCS Diagnosis Code', 'CCS Procedure Description', 'APR DRG Code','APR MDC Code', 'APR Medical Surgical Description',
                    'Emergency Department Indicator', 'Payment Typology 1',
       'Payment Typology 2', 'Payment Typology 3', 'Birth Weight','Abortion Edit Indicator',
      'Total Charges', 'Total Costs',]
df3 = df2.drop(columns = dropping_columns)

# %%
df3.shape
# Out:
# (64116, 15)

# %%
df3.head()
# Out:
#   Hospital Service Area Hospital County                     Facility Name  \
# 0         Hudson Valley     Westchester  Montefiore New Rochelle Hospital
# 1         Hudson Valley        Sullivan  Catskill Regional Medical Center
# 2         Hudson Valley        Sullivan  Catskill Regional Medical Center
# 3         Hudson Valley        Sullivan  Catskill Regional Medical Center
# 4         New York City       Manhattan              Mount Sinai Hospital
#
#      Age Group Zip Code - 3 digits Gender Length of Stay Type of Admission  \
# 0     18 to 29                 108      M             27         Emergency
# 1  70 or Older                 127      F              2         Emergency
# 2      0 to 17                 127      F              2         Emergency
# 3     18 to 29                 OOS      M              3         Emergency
# 4      0 to 17                 100      F              2            Urgent
#
#    Discharge Year                          CCS Diagnosis Description  \
# 0            2017  Pneumonia (except that caused by tuberculosis ...
# 1            2017                                          Influenza
# 2            2017                                   Acute bronchitis
# 3            2017                            Pulmonary heart disease
# 4            2017                                             Asthma
#
#              APR DRG Description  \
# 0                Other pneumonia
# 1                Other pneumonia
# 2  Bronchiolitis & RSV pneumonia
# 3             Pulmonary embolism
# 4                         Asthma
#
#                                 APR MDC Description  \
# 0  Diseases and Disorders of the Respiratory System
# 1  Diseases and Disorders of the Respiratory System
# 2  Diseases and Disorders of the Respiratory System
# 3  Diseases and Disorders of the Respiratory System
# 4  Diseases and Disorders of the Respiratory System
#
#    APR Severity of Illness Code APR Severity of Illness Description  \
# 0                             2                            Moderate
# 1                             2                            Moderate
# 2                             1                               Minor
# 3                             1                               Minor
# 4                             2                            Moderate
#
#   APR Risk of Mortality
# 0                 Minor
# 1                 Minor
# 2                 Minor
# 3                 Minor
# 4                 Minor

# %%
df3.columns
# Out:
# Index(['Hospital Service Area', 'Hospital County', 'Facility Name',
#        'Age Group', 'Zip Code - 3 digits', 'Gender', 'Length of Stay',
#        'Type of Admission', 'Discharge Year', 'CCS Diagnosis Description',
#        'APR DRG Description', 'APR MDC Description',
#        'APR Severity of Illness Code', 'APR Severity of Illness Description',
#        'APR Risk of Mortality'],
#       dtype='object')

# %%
df3.head()
# Out:
#   Hospital Service Area Hospital County                     Facility Name  \
# 0         Hudson Valley     Westchester  Montefiore New Rochelle Hospital
# 1         Hudson Valley        Sullivan  Catskill Regional Medical Center
# 2         Hudson Valley        Sullivan  Catskill Regional Medical Center
# 3         Hudson Valley        Sullivan  Catskill Regional Medical Center
# 4         New York City       Manhattan              Mount Sinai Hospital
#
#      Age Group Zip Code - 3 digits Gender Length of Stay Type of Admission  \
# 0     18 to 29                 108      M             27         Emergency
# 1  70 or Older                 127      F              2         Emergency
# 2      0 to 17                 127      F              2         Emergency
# 3     18 to 29                 OOS      M              3         Emergency
# 4      0 to 17                 100      F              2            Urgent
#
#    Discharge Year                          CCS Diagnosis Description  \
# 0            2017  Pneumonia (except that caused by tuberculosis ...
# 1            2017                                          Influenza
# 2            2017                                   Acute bronchitis
# 3            2017                            Pulmonary heart disease
# 4            2017                                             Asthma
#
#              APR DRG Description  \
# 0                Other pneumonia
# 1                Other pneumonia
# 2  Bronchiolitis & RSV pneumonia
# 3             Pulmonary embolism
# 4                         Asthma
#
#                                 APR MDC Description  \
# 0  Diseases and Disorders of the Respiratory System
# 1  Diseases and Disorders of the Respiratory System
# 2  Diseases and Disorders of the Respiratory System
# 3  Diseases and Disorders of the Respiratory System
# 4  Diseases and Disorders of the Respiratory System
#
#    APR Severity of Illness Code APR Severity of Illness Description  \
# 0                             2                            Moderate
# 1                             2                            Moderate
# 2                             1                               Minor
# 3                             1                               Minor
# 4                             2                            Moderate
#
#   APR Risk of Mortality
# 0                 Minor
# 1                 Minor
# 2                 Minor
# 3                 Minor
# 4                 Minor

# %%
df3['Hospital Service Area'].unique()
# Out:
# array(['Hudson Valley', 'New York City', 'Finger Lakes',
#        'Capital/Adirond', 'Western NY', 'Long Island', 'Central NY', nan,
#        'Southern Tier'], dtype=object)

# %%
df4 = df3.dropna()

# %%
df4.shape
# Out:
# (63316, 15)

# %%
df4.to_csv('2017_Discharge_updated', index = False)
