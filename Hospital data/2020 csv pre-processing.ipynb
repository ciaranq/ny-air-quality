# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('../../Hospital_Inpatient_Discharges_2020.csv')

# %%
df.head()
# Out:
#   Hospital Service Area Hospital County  Operating Certificate Number  \
# 0         New York City           Bronx                     7000006.0
# 1         New York City           Bronx                     7000006.0
# 2         New York City           Bronx                     7000006.0
# 3         New York City           Bronx                     7000006.0
# 4         New York City           Bronx                     7000006.0
#
#    Permanent Facility Id                                      Facility Name  \
# 0                 3058.0  Montefiore Med Center - Jack D Weiler Hosp of ...
# 1                 1168.0       Montefiore Medical Center-Wakefield Hospital
# 2                 1168.0       Montefiore Medical Center-Wakefield Hospital
# 3                 1169.0  Montefiore Medical Center - Henry & Lucy Moses...
# 4                 1169.0  Montefiore Medical Center - Henry & Lucy Moses...
#
#   Age Group Zip Code - 3 digits Gender                    Race  \
# 0  50 to 69                 104      F  Black/African American
# 1  18 to 29                 104      F  Black/African American
# 2  50 to 69                 104      F              Other Race
# 3   0 to 17                 104      M              Other Race
# 4   0 to 17                 104      M              Other Race
#
#            Ethnicity  ... APR Severity of Illness Description  \
# 0  Not Span/Hispanic  ...                            Moderate
# 1  Not Span/Hispanic  ...                            Moderate
# 2   Spanish/Hispanic  ...                            Moderate
# 3   Spanish/Hispanic  ...                            Moderate
# 4   Spanish/Hispanic  ...                            Moderate
#
#   APR Risk of Mortality APR Medical Surgical Description  \
# 0              Moderate                          Medical
# 1                 Minor                          Medical
# 2                 Major                          Medical
# 3              Moderate                          Medical
# 4                 Minor                          Medical
#
#        Payment Typology 1 Payment Typology 2 Payment Typology 3 Birth Weight  \
# 0                Medicare                NaN                NaN          NaN
# 1                Medicaid                NaN                NaN          NaN
# 2                Medicare           Medicaid                NaN          NaN
# 3                Medicaid                NaN                NaN          NaN
# 4  Blue Cross/Blue Shield                NaN                NaN          NaN
#
#   Emergency Department Indicator  Total Charges Total Costs
# 0                              Y      214778.30    40532.42
# 1                              N       33385.21     8996.74
# 2                              Y       16581.52     1735.53
# 3                              N       14086.86     3438.63
# 4                              Y       28222.99     6886.04
#
# [5 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['Hospital Service Area', 'Hospital County',
#        'Operating Certificate Number', 'Permanent Facility Id',
#        'Facility Name', 'Age Group', 'Zip Code - 3 digits', 'Gender', 'Race',
#        'Ethnicity', 'Length of Stay', 'Type of Admission',
#        'Patient Disposition', 'Discharge Year', 'CCSR Diagnosis Code',
#        'CCSR Diagnosis Description', 'CCSR Procedure Code',
#        'CCSR Procedure Description', 'APR DRG Code', 'APR DRG Description',
#        'APR MDC Code', 'APR MDC Description', 'APR Severity of Illness Code',
#        'APR Severity of Illness Description', 'APR Risk of Mortality',
#        'APR Medical Surgical Description', 'Payment Typology 1',
#        'Payment Typology 2', 'Payment Typology 3', 'Birth Weight',
#        'Emergency Department Indicator', 'Total Charges', 'Total Costs'],
#       dtype='object')

# %%
condition = df['APR Risk of Mortality'] == 'Minor'
df1 = df[condition]

# %%
df1.shape
# Out:
# (1070078, 33)

# %%
df1.head()
# Out:
#    Hospital Service Area Hospital County  Operating Certificate Number  \
# 1          New York City           Bronx                     7000006.0
# 4          New York City           Bronx                     7000006.0
# 5          New York City           Bronx                     7000006.0
# 8          New York City           Bronx                     7000006.0
# 12         New York City           Bronx                     7000006.0
#
#     Permanent Facility Id                                      Facility Name  \
# 1                  1168.0       Montefiore Medical Center-Wakefield Hospital
# 4                  1169.0  Montefiore Medical Center - Henry & Lucy Moses...
# 5                  1169.0  Montefiore Medical Center - Henry & Lucy Moses...
# 8                  1169.0  Montefiore Medical Center - Henry & Lucy Moses...
# 12                 1169.0  Montefiore Medical Center - Henry & Lucy Moses...
#
#    Age Group Zip Code - 3 digits Gender                    Race  \
# 1   18 to 29                 104      F  Black/African American
# 4    0 to 17                 104      M              Other Race
# 5    0 to 17                 104      M              Other Race
# 8    0 to 17                 104      F              Other Race
# 12  30 to 49                 104      F              Other Race
#
#             Ethnicity  ... APR Severity of Illness Description  \
# 1   Not Span/Hispanic  ...                            Moderate
# 4    Spanish/Hispanic  ...                            Moderate
# 5             Unknown  ...                            Moderate
# 8    Spanish/Hispanic  ...                               Minor
# 12   Spanish/Hispanic  ...                            Moderate
#
#    APR Risk of Mortality APR Medical Surgical Description  \
# 1                  Minor                          Medical
# 4                  Minor                          Medical
# 5                  Minor                          Medical
# 8                  Minor                         Surgical
# 12                 Minor                          Medical
#
#         Payment Typology 1 Payment Typology 2 Payment Typology 3 Birth Weight  \
# 1                 Medicaid                NaN                NaN          NaN
# 4   Blue Cross/Blue Shield                NaN                NaN          NaN
# 5                 Medicaid                NaN                NaN          NaN
# 8                 Medicaid                NaN                NaN          NaN
# 12                Medicaid                NaN                NaN          NaN
#
#    Emergency Department Indicator  Total Charges Total Costs
# 1                               N       33385.21     8996.74
# 4                               Y       28222.99     6886.04
# 5                               Y       16625.63     3639.43
# 8                               Y       37288.49     7339.09
# 12                              Y       52177.90     7726.46
#
# [5 rows x 33 columns]

# %%
#listing the categories in the MDC description

df1['APR MDC Description'].unique()
# Out:
# array(['PREGNANCY, CHILDBIRTH AND THE PUERPERIUM',
#        'DISEASES AND DISORDERS OF THE EAR, NOSE, MOUTH AND THROAT',
#        'INFECTIOUS AND PARASITIC DISEASES (SYSTEMIC OR UNSPECIFIED SITES)',
#        'DISEASES AND DISORDERS OF THE DIGESTIVE SYSTEM',
#        'ALCOHOL/DRUG USE AND ALCOHOL/DRUG INDUCED ORGANIC MENTAL DISORDERS',
#        'DISEASES AND DISORDERS OF THE CIRCULATORY SYSTEM',
#        'DISEASES AND DISORDERS OF THE MUSCULOSKELETAL SYSTEM AND CONNECTIVE TISSUE',
#        'DISEASES AND DISORDERS OF THE SKIN, SUBCUTANEOUS TISSUE AND BREAST',
#        'DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM',
#        'DISEASES AND DISORDERS OF THE NERVOUS SYSTEM',
#        'NEWBORNS AND OTHER NEONATES WITH CONDITIONS ORIGINATING IN THE PERINATAL PERIOD',
#        'DISEASES AND DISORDERS OF THE KIDNEY AND URINARY TRACT',
#        'ENDOCRINE, NUTRITIONAL AND METABOLIC DISEASES AND DISORDERS',
#        'MENTAL DISEASES AND DISORDERS',
#        'DISEASES AND DISORDERS OF THE HEPATOBILIARY SYSTEM AND PANCREAS',
#        'DISEASES AND DISORDERS OF THE MALE REPRODUCTIVE SYSTEM',
#        'FACTORS INFLUENCING HEALTH STATUS AND OTHER CONTACTS WITH HEALTH SERVICES',
#        'DISEASES AND DISORDERS OF THE BLOOD AND BLOOD FORMING ORGANS AND IMMUNOLOGICAL DISORDERS',
#        'MYELOPROLIFERATIVE DISEASES AND DISORDERS, AND POORLY DIFFERENTIATED NEOPLASM',
#        'INJURIES, POISONINGS AND TOXIC EFFECTS OF DRUGS',
#        'DISEASES AND DISORDERS OF THE FEMALE REPRODUCTIVE SYSTEM',
#        'DISEASES AND DISORDERS OF THE EYE', 'MULTIPLE SIGNIFICANT TRAUMA',
#        'HUMAN IMMUNODEFICIENCY VIRUS INFECTIONS', 'BURNS'], dtype=object)

# %%
#filtering by potential respiratory conditions relating to pollution in the 'APR MDC Description' column, 
#resetting index

filtered = ['DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM']

condition = df1['APR MDC Description'].isin(filtered)
df2 = df1[condition]
df2 = df2.reset_index(drop = True)

# %%
df2.shape
# Out:
# (37805, 33)

# %%
df2.head()
# Out:
#   Hospital Service Area Hospital County  Operating Certificate Number  \
# 0         New York City           Bronx                     7000006.0
# 1         New York City           Bronx                     7000006.0
# 2         New York City           Bronx                     7000006.0
# 3         New York City           Bronx                     7000006.0
# 4         New York City           Bronx                     7000006.0
#
#    Permanent Facility Id                                      Facility Name  \
# 0                 1169.0  Montefiore Medical Center - Henry & Lucy Moses...
# 1                 1169.0  Montefiore Medical Center - Henry & Lucy Moses...
# 2                 1168.0       Montefiore Medical Center-Wakefield Hospital
# 3                 1168.0       Montefiore Medical Center-Wakefield Hospital
# 4                 1169.0  Montefiore Medical Center - Henry & Lucy Moses...
#
#   Age Group Zip Code - 3 digits Gender                    Race  \
# 0  18 to 29                 104      M  Black/African American
# 1   0 to 17                 NaN      F              Other Race
# 2  30 to 49                 104      F              Other Race
# 3  30 to 49                 104      M  Black/African American
# 4  50 to 69                 104      F              Other Race
#
#            Ethnicity  ... APR Severity of Illness Description  \
# 0  Not Span/Hispanic  ...                               Minor
# 1   Spanish/Hispanic  ...                               Minor
# 2  Not Span/Hispanic  ...                               Minor
# 3  Not Span/Hispanic  ...                            Moderate
# 4   Spanish/Hispanic  ...                            Moderate
#
#   APR Risk of Mortality APR Medical Surgical Description  \
# 0                 Minor                          Medical
# 1                 Minor                          Medical
# 2                 Minor                          Medical
# 3                 Minor                          Medical
# 4                 Minor                          Medical
#
#          Payment Typology 1 Payment Typology 2 Payment Typology 3  \
# 0                  Medicaid                NaN                NaN
# 1                  Medicaid                NaN                NaN
# 2  Private Health Insurance                NaN                NaN
# 3                  Medicare           Medicaid                NaN
# 4                  Medicaid                NaN                NaN
#
#   Birth Weight Emergency Department Indicator  Total Charges Total Costs
# 0          NaN                              Y       16673.87     3887.30
# 1          NaN                              Y       16101.66     3692.90
# 2          NaN                              Y       34857.21     4646.98
# 3          NaN                              Y       34579.28     5824.23
# 4          NaN                              Y       59855.70     9875.93
#
# [5 rows x 33 columns]

# %%
#dropping irrelevant columns
dropping_columns = [ 'Operating Certificate Number', 'Permanent Facility Id', 'Race', 'Ethnicity', 'Patient Disposition','CCSR Procedure Code',
      'CCSR Diagnosis Code', 'CCSR Procedure Description', 'APR DRG Code','APR MDC Code', 'APR Medical Surgical Description',
                    'Emergency Department Indicator', 'Payment Typology 1',
       'Payment Typology 2', 'Payment Typology 3', 'Birth Weight',
      'Total Charges', 'Total Costs',]
df3 = df2.drop(columns = dropping_columns)

# %%
df3.shape
# Out:
# (37805, 15)

# %%
df3.head()
# Out:
#   Hospital Service Area Hospital County  \
# 0         New York City           Bronx
# 1         New York City           Bronx
# 2         New York City           Bronx
# 3         New York City           Bronx
# 4         New York City           Bronx
#
#                                        Facility Name Age Group  \
# 0  Montefiore Medical Center - Henry & Lucy Moses...  18 to 29
# 1  Montefiore Medical Center - Henry & Lucy Moses...   0 to 17
# 2       Montefiore Medical Center-Wakefield Hospital  30 to 49
# 3       Montefiore Medical Center-Wakefield Hospital  30 to 49
# 4  Montefiore Medical Center - Henry & Lucy Moses...  50 to 69
#
#   Zip Code - 3 digits Gender Length of Stay Type of Admission  Discharge Year  \
# 0                 104      M              1         Emergency            2020
# 1                 NaN      F              1         Emergency            2020
# 2                 104      F              2         Emergency            2020
# 3                 104      M              3         Emergency            2020
# 4                 104      F              4         Emergency            2020
#
#   CCSR Diagnosis Description APR DRG Description  \
# 0                     ASTHMA              ASTHMA
# 1                     ASTHMA              ASTHMA
# 2                     ASTHMA              ASTHMA
# 3                     ASTHMA              ASTHMA
# 4                     ASTHMA              ASTHMA
#
#                                 APR MDC Description  \
# 0  DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM
# 1  DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM
# 2  DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM
# 3  DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM
# 4  DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM
#
#    APR Severity of Illness Code APR Severity of Illness Description  \
# 0                             1                               Minor
# 1                             1                               Minor
# 2                             1                               Minor
# 3                             2                            Moderate
# 4                             2                            Moderate
#
#   APR Risk of Mortality
# 0                 Minor
# 1                 Minor
# 2                 Minor
# 3                 Minor
# 4                 Minor

# %%
df3.columns
# Out:
# Index(['Hospital Service Area', 'Hospital County', 'Facility Name',
#        'Age Group', 'Zip Code - 3 digits', 'Gender', 'Length of Stay',
#        'Type of Admission', 'Discharge Year', 'CCSR Diagnosis Description',
#        'APR DRG Description', 'APR MDC Description',
#        'APR Severity of Illness Code', 'APR Severity of Illness Description',
#        'APR Risk of Mortality'],
#       dtype='object')

# %%
df3.head()
# Out:
#   Hospital Service Area Hospital County  \
# 0         New York City           Bronx
# 1         New York City           Bronx
# 2         New York City           Bronx
# 3         New York City           Bronx
# 4         New York City           Bronx
#
#                                        Facility Name Age Group  \
# 0  Montefiore Medical Center - Henry & Lucy Moses...  18 to 29
# 1  Montefiore Medical Center - Henry & Lucy Moses...   0 to 17
# 2       Montefiore Medical Center-Wakefield Hospital  30 to 49
# 3       Montefiore Medical Center-Wakefield Hospital  30 to 49
# 4  Montefiore Medical Center - Henry & Lucy Moses...  50 to 69
#
#   Zip Code - 3 digits Gender Length of Stay Type of Admission  Discharge Year  \
# 0                 104      M              1         Emergency            2020
# 1                 NaN      F              1         Emergency            2020
# 2                 104      F              2         Emergency            2020
# 3                 104      M              3         Emergency            2020
# 4                 104      F              4         Emergency            2020
#
#   CCSR Diagnosis Description APR DRG Description  \
# 0                     ASTHMA              ASTHMA
# 1                     ASTHMA              ASTHMA
# 2                     ASTHMA              ASTHMA
# 3                     ASTHMA              ASTHMA
# 4                     ASTHMA              ASTHMA
#
#                                 APR MDC Description  \
# 0  DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM
# 1  DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM
# 2  DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM
# 3  DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM
# 4  DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM
#
#    APR Severity of Illness Code APR Severity of Illness Description  \
# 0                             1                               Minor
# 1                             1                               Minor
# 2                             1                               Minor
# 3                             2                            Moderate
# 4                             2                            Moderate
#
#   APR Risk of Mortality
# 0                 Minor
# 1                 Minor
# 2                 Minor
# 3                 Minor
# 4                 Minor

# %%
df3['Hospital Service Area'].unique()
# Out:
# array(['New York City', 'Capital/Adirond', 'Hudson Valley', 'Long Island',
#        nan, 'Central NY', 'Western NY', 'Finger Lakes', 'Southern Tier'],
#       dtype=object)

# %%
df4 = df3.dropna()

# %%
df4.shape
# Out:
# (37177, 15)

# %%
df4.to_csv('2020_Discharge_updated', index = False)
