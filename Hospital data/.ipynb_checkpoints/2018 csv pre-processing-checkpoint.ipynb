# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('../../Hospital_Inpatient_Discharges_2018.csv')

# %%
df.head()
# Out:
#   Hospital Service Area Hospital County  Operating Certificate Number  \
# 0       Capital/Adirond        Columbia                     1001000.0
# 1         New York City       Manhattan                     7002009.0
# 2         New York City       Manhattan                     7002009.0
# 3         New York City           Kings                     7001016.0
# 4         New York City       Manhattan                     7002054.0
#
#    Permanent Facility Id                                      Facility Name  \
# 0                  146.0                         Columbia Memorial Hospital
# 1                 1445.0                             Harlem Hospital Center
# 2                 1445.0                             Harlem Hospital Center
# 3                 1301.0                       Kings County Hospital Center
# 4                 1464.0  New York-Presbyterian Hospital - Columbia Pres...
#
#   Age Group Zip Code - 3 digits Gender                    Race  \
# 0  50 to 69                 125      F                   White
# 1  50 to 69                 100      F  Black/African American
# 2  50 to 69                 100      F  Black/African American
# 3  18 to 29                 112      M  Black/African American
# 4   0 to 17                 104      M            Multi-racial
#
#            Ethnicity  ... APR Severity of Illness Description  \
# 0  Not Span/Hispanic  ...                               Major
# 1  Not Span/Hispanic  ...                             Extreme
# 2  Not Span/Hispanic  ...                            Moderate
# 3  Not Span/Hispanic  ...                            Moderate
# 4  Not Span/Hispanic  ...                               Major
#
#   APR Risk of Mortality APR Medical Surgical Description  \
# 0                 Major                          Medical
# 1               Extreme                         Surgical
# 2                 Minor                          Medical
# 3                 Minor                          Medical
# 4              Moderate                          Medical
#
#           Payment Typology 1 Payment Typology 2 Payment Typology 3  \
# 0  Managed Care, Unspecified           Self-Pay                NaN
# 1                   Medicare           Medicaid                NaN
# 2                   Medicaid                NaN                NaN
# 3                   Medicaid           Medicaid                NaN
# 4                   Medicaid           Medicaid           Self-Pay
#
#   Birth Weight Emergency Department Indicator  Total Charges Total Costs
# 0          NaN                           True       17591.41     3570.06
# 1          NaN                           True      106190.21    78913.24
# 2          NaN                          False        5600.00     4161.53
# 3          NaN                           True       15965.54    11341.30
# 4          NaN                           True       36846.83    10240.02
#
# [5 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['Hospital Service Area', 'Hospital County',
#        'Operating Certificate Number', 'Permanent Facility Id',
#        'Facility Name', 'Age Group', 'Zip Code - 3 digits', 'Gender', 'Race',
#        'Ethnicity', 'Length of Stay', 'Type of Admission',
#        'Patient Disposition', 'Discharge Year', 'CCSR Diagnosis Code',
#        'CCSR Diagnosis Description', 'CCSR Procedure Code',
#        'CCSR Procedure Description', 'APR DRG Code', 'APR DRG Description',
#        'APR MDC Code', 'APR MDC Description', 'APR Severity of Illness Code',
#        'APR Severity of Illness Description', 'APR Risk of Mortality',
#        'APR Medical Surgical Description', 'Payment Typology 1',
#        'Payment Typology 2', 'Payment Typology 3', 'Birth Weight',
#        'Emergency Department Indicator', 'Total Charges', 'Total Costs'],
#       dtype='object')

# %%
condition = df['APR Risk of Mortality'] == 'Minor'
df1 = df[condition]

# %%
df1.shape
# Out:
# (1299998, 33)

# %%
df1.head()
# Out:
#   Hospital Service Area Hospital County  Operating Certificate Number  \
# 2         New York City       Manhattan                     7002009.0
# 3         New York City           Kings                     7001016.0
# 6         New York City       Manhattan                     7002009.0
# 7         New York City       Manhattan                     7002009.0
# 9         New York City           Kings                     7001020.0
#
#    Permanent Facility Id                 Facility Name Age Group  \
# 2                 1445.0        Harlem Hospital Center  50 to 69
# 3                 1301.0  Kings County Hospital Center  18 to 29
# 6                 1445.0        Harlem Hospital Center  50 to 69
# 7                 1445.0        Harlem Hospital Center  18 to 29
# 9                 1305.0     Maimonides Medical Center   0 to 17
#
#   Zip Code - 3 digits Gender                    Race          Ethnicity  ...  \
# 2                 100      F  Black/African American  Not Span/Hispanic  ...
# 3                 112      M  Black/African American  Not Span/Hispanic  ...
# 6                 100      F  Black/African American  Not Span/Hispanic  ...
# 7                 100      F  Black/African American  Not Span/Hispanic  ...
# 9                 112      F              Other Race  Not Span/Hispanic  ...
#
#   APR Severity of Illness Description APR Risk of Mortality  \
# 2                            Moderate                 Minor
# 3                            Moderate                 Minor
# 6                               Minor                 Minor
# 7                            Moderate                 Minor
# 9                            Moderate                 Minor
#
#   APR Medical Surgical Description  Payment Typology 1 Payment Typology 2  \
# 2                          Medical            Medicaid                NaN
# 3                          Medical            Medicaid           Medicaid
# 6                          Medical            Medicare           Medicaid
# 7                          Medical            Medicaid                NaN
# 9                          Medical            Medicaid           Medicaid
#
#   Payment Typology 3 Birth Weight Emergency Department Indicator  \
# 2                NaN          NaN                          False
# 3                NaN          NaN                           True
# 6                NaN          NaN                           True
# 7                NaN          NaN                           True
# 9           Self-Pay          NaN                          False
#
#    Total Charges Total Costs
# 2        5600.00     4161.53
# 3       15965.54    11341.30
# 6       12290.21     9133.24
# 7        6440.21     4785.92
# 9        7983.00     3447.96
#
# [5 rows x 33 columns]

# %%
#listing the categories in the MDC description

df1['APR MDC Description'].unique()
# Out:
# array(['MENTAL DISEASES AND DISORDERS',
#        'DISEASES AND DISORDERS OF THE CIRCULATORY SYSTEM',
#        'DISEASES AND DISORDERS OF THE KIDNEY AND URINARY TRACT',
#        'DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM',
#        'DISEASES AND DISORDERS OF THE NERVOUS SYSTEM',
#        'NEWBORNS AND OTHER NEONATES WITH CONDITIONS ORIGINATING IN THE PERINATAL PERIOD',
#        'DISEASES AND DISORDERS OF THE DIGESTIVE SYSTEM',
#        'PREGNANCY, CHILDBIRTH AND THE PUERPERIUM',
#        'INJURIES, POISONINGS AND TOXIC EFFECTS OF DRUGS',
#        'ALCOHOL/DRUG USE AND ALCOHOL/DRUG INDUCED ORGANIC MENTAL DISORDERS',
#        'DISEASES AND DISORDERS OF THE FEMALE REPRODUCTIVE SYSTEM',
#        'DISEASES AND DISORDERS OF THE MUSCULOSKELETAL SYSTEM AND CONNECTIVE TISSUE',
#        'ENDOCRINE, NUTRITIONAL AND METABOLIC DISEASES AND DISORDERS',
#        'DISEASES AND DISORDERS OF THE SKIN, SUBCUTANEOUS TISSUE AND BREAST',
#        'DISEASES AND DISORDERS OF THE HEPATOBILIARY SYSTEM AND PANCREAS',
#        'FACTORS INFLUENCING HEALTH STATUS AND OTHER CONTACTS WITH HEALTH SERVICES',
#        'MYELOPROLIFERATIVE DISEASES AND DISORDERS, AND POORLY DIFFERENTIATED NEOPLASM',
#        'DISEASES AND DISORDERS OF THE BLOOD AND BLOOD FORMING ORGANS AND IMMUNOLOGICAL DISORDERS',
#        'INFECTIOUS AND PARASITIC DISEASES (SYSTEMIC OR UNSPECIFIED SITES)',
#        'DISEASES AND DISORDERS OF THE EAR, NOSE, MOUTH AND THROAT',
#        'DISEASES AND DISORDERS OF THE MALE REPRODUCTIVE SYSTEM',
#        'DISEASES AND DISORDERS OF THE EYE', 'BURNS',
#        'MULTIPLE SIGNIFICANT TRAUMA',
#        'HUMAN IMMUNODEFICIENCY VIRUS INFECTIONS'], dtype=object)

# %%
#filtering by potential respiratory conditions relating to pollution in the 'APR MDC Description' column, 
#resetting index

filtered = ['DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM']

condition = df1['APR MDC Description'].isin(filtered)
df2 = df1[condition]
df2 = df2.reset_index(drop = True)

# %%
df2.shape
# Out:
# (62899, 33)

# %%
df2.head()
# Out:
#   Hospital Service Area Hospital County  Operating Certificate Number  \
# 0         New York City           Kings                     7001020.0
# 1            Western NY            Erie                     1401014.0
# 2         New York City       Manhattan                     7002009.0
# 3         New York City       Manhattan                     7002009.0
# 4          Finger Lakes         Ontario                     3402000.0
#
#    Permanent Facility Id                       Facility Name Age Group  \
# 0                 1305.0           Maimonides Medical Center   0 to 17
# 1                  208.0  John R. Oishei Children's Hospital   0 to 17
# 2                 1445.0              Harlem Hospital Center  30 to 49
# 3                 1445.0              Harlem Hospital Center  50 to 69
# 4                  671.0             Geneva General Hospital  50 to 69
#
#   Zip Code - 3 digits Gender                    Race          Ethnicity  ...  \
# 0                 112      F              Other Race  Not Span/Hispanic  ...
# 1                 142      M  Black/African American  Not Span/Hispanic  ...
# 2                 104      F  Black/African American  Not Span/Hispanic  ...
# 3                 100      M  Black/African American  Not Span/Hispanic  ...
# 4                 131      F                   White  Not Span/Hispanic  ...
#
#   APR Severity of Illness Description APR Risk of Mortality  \
# 0                            Moderate                 Minor
# 1                               Minor                 Minor
# 2                               Minor                 Minor
# 3                            Moderate                 Minor
# 4                               Major                 Minor
#
#   APR Medical Surgical Description      Payment Typology 1 Payment Typology 2  \
# 0                          Medical                Medicaid           Medicaid
# 1                          Medical  Blue Cross/Blue Shield           Self-Pay
# 2                          Medical                Medicaid                NaN
# 3                          Medical                Medicaid           Medicaid
# 4                          Medical  Blue Cross/Blue Shield                NaN
#
#   Payment Typology 3 Birth Weight Emergency Department Indicator  \
# 0           Self-Pay          NaN                          False
# 1                NaN          NaN                           True
# 2                NaN          NaN                           True
# 3                NaN          NaN                           True
# 4                NaN          NaN                           True
#
#    Total Charges Total Costs
# 0        7983.00     3447.96
# 1        5632.90     3067.34
# 2        6440.21     4785.92
# 3       25790.21    19165.50
# 4       10495.12     3555.97
#
# [5 rows x 33 columns]

# %%
#dropping irrelevant columns
dropping_columns = [ 'Operating Certificate Number', 'Permanent Facility Id', 'Race', 'Ethnicity', 'Patient Disposition','CCSR Procedure Code',
      'CCSR Diagnosis Code', 'CCSR Procedure Description', 'APR DRG Code','APR MDC Code', 'APR Medical Surgical Description',
                    'Emergency Department Indicator', 'Payment Typology 1',
       'Payment Typology 2', 'Payment Typology 3', 'Birth Weight',
      'Total Charges', 'Total Costs',]
df3 = df2.drop(columns = dropping_columns)

# %%
df3.shape
# Out:
# (62899, 15)

# %%
df3.head()
# Out:
#   Hospital Service Area Hospital County                       Facility Name  \
# 0         New York City           Kings           Maimonides Medical Center
# 1            Western NY            Erie  John R. Oishei Children's Hospital
# 2         New York City       Manhattan              Harlem Hospital Center
# 3         New York City       Manhattan              Harlem Hospital Center
# 4          Finger Lakes         Ontario             Geneva General Hospital
#
#   Age Group Zip Code - 3 digits Gender Length of Stay Type of Admission  \
# 0   0 to 17                 112      F              1         Emergency
# 1   0 to 17                 142      M              1         Emergency
# 2  30 to 49                 104      F              1         Emergency
# 3  50 to 69                 100      M              5         Emergency
# 4  50 to 69                 131      F              3         Emergency
#
#    Discharge Year                         CCSR Diagnosis Description  \
# 0            2018     PNEUMONIA (EXCEPT THAT CAUSED BY TUBERCULOSIS)
# 1            2018                                             ASTHMA
# 2            2018                                             ASTHMA
# 3            2018     PNEUMONIA (EXCEPT THAT CAUSED BY TUBERCULOSIS)
# 4            2018  CHRONIC OBSTRUCTIVE PULMONARY DISEASE AND BRON...
#
#                      APR DRG Description  \
# 0                        OTHER PNEUMONIA
# 1                                 ASTHMA
# 2                                 ASTHMA
# 3                        OTHER PNEUMONIA
# 4  CHRONIC OBSTRUCTIVE PULMONARY DISEASE
#
#                                 APR MDC Description  \
# 0  DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM
# 1  DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM
# 2  DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM
# 3  DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM
# 4  DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM
#
#    APR Severity of Illness Code APR Severity of Illness Description  \
# 0                           2.0                            Moderate
# 1                           1.0                               Minor
# 2                           1.0                               Minor
# 3                           2.0                            Moderate
# 4                           3.0                               Major
#
#   APR Risk of Mortality
# 0                 Minor
# 1                 Minor
# 2                 Minor
# 3                 Minor
# 4                 Minor

# %%
df3.columns
# Out:
# Index(['Hospital Service Area', 'Hospital County', 'Facility Name',
#        'Age Group', 'Zip Code - 3 digits', 'Gender', 'Length of Stay',
#        'Type of Admission', 'Discharge Year', 'CCSR Diagnosis Description',
#        'APR DRG Description', 'APR MDC Description',
#        'APR Severity of Illness Code', 'APR Severity of Illness Description',
#        'APR Risk of Mortality'],
#       dtype='object')

# %%
df3.head()
# Out:
#   Hospital Service Area Hospital County                       Facility Name  \
# 0         New York City           Kings           Maimonides Medical Center
# 1            Western NY            Erie  John R. Oishei Children's Hospital
# 2         New York City       Manhattan              Harlem Hospital Center
# 3         New York City       Manhattan              Harlem Hospital Center
# 4          Finger Lakes         Ontario             Geneva General Hospital
#
#   Age Group Zip Code - 3 digits Gender Length of Stay Type of Admission  \
# 0   0 to 17                 112      F              1         Emergency
# 1   0 to 17                 142      M              1         Emergency
# 2  30 to 49                 104      F              1         Emergency
# 3  50 to 69                 100      M              5         Emergency
# 4  50 to 69                 131      F              3         Emergency
#
#    Discharge Year                         CCSR Diagnosis Description  \
# 0            2018     PNEUMONIA (EXCEPT THAT CAUSED BY TUBERCULOSIS)
# 1            2018                                             ASTHMA
# 2            2018                                             ASTHMA
# 3            2018     PNEUMONIA (EXCEPT THAT CAUSED BY TUBERCULOSIS)
# 4            2018  CHRONIC OBSTRUCTIVE PULMONARY DISEASE AND BRON...
#
#                      APR DRG Description  \
# 0                        OTHER PNEUMONIA
# 1                                 ASTHMA
# 2                                 ASTHMA
# 3                        OTHER PNEUMONIA
# 4  CHRONIC OBSTRUCTIVE PULMONARY DISEASE
#
#                                 APR MDC Description  \
# 0  DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM
# 1  DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM
# 2  DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM
# 3  DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM
# 4  DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM
#
#    APR Severity of Illness Code APR Severity of Illness Description  \
# 0                           2.0                            Moderate
# 1                           1.0                               Minor
# 2                           1.0                               Minor
# 3                           2.0                            Moderate
# 4                           3.0                               Major
#
#   APR Risk of Mortality
# 0                 Minor
# 1                 Minor
# 2                 Minor
# 3                 Minor
# 4                 Minor

# %%
df3['Hospital Service Area'].unique()
# Out:
# array(['New York City', 'Western NY', 'Finger Lakes', 'Long Island',
#        'Hudson Valley', 'Southern Tier', 'Capital/Adirond', 'Central NY',
#        nan], dtype=object)

# %%
df4 = df3.dropna()

# %%
df4.shape
# Out:
# (61992, 15)

# %%
df4.to_csv('2018_Discharge_updated', index = False)
